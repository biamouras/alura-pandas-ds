# %% [markdown]
# # 1. Introdução

# %% [markdown]
# ## Trabalhando com dados

# %%
import pandas as pd
# definir o máximo de linhas e colunas para mostrar pelo pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 10)

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python para Data Science/03_funcoes_pacotes_pandas/data/db.csv', sep = ';')

# %%
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
dataset.dtypes # fornece os tipos de cada coluna
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[['Quilometragem', 'Valor']].describe() # fornece um resumo estatístico das variáveis
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info() # mistura as informações de dtypes e describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %% [markdown]
# # 2. Tuplas

# %% [markdown]
# Tuplas são sequências imutáveis, que são utilizadas para armazenar coleções de itens. É possível criar tuplas de diferentes modos:
#
#   * Colocando os valores entre `( )`

# %%
(1, 2, 3)
# Out:
# (1, 2, 3)

# %% [markdown]
# * Separando os itens por `,`

# %%
1, 2, 3
# Out:
# (1, 2, 3)

# %% [markdown]
#  * Usando `tuple()`

# %%
tuple([1, 2, 3])
# Out:
# (1, 2, 3)

# %% [markdown]
# ## Seleções em tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DSS')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DSS')

# %% [markdown]
# A seleção em tuplas é igual à seleção em listas.

# %%
nomes_carros[0]
# Out:
# 'Jetta Variant'

# %%
nomes_carros[1]
# Out:
# 'Passat'

# %%
nomes_carros[-1]
# Out:
# 'DSS'

# %%
nomes_carros[1:3] # do mesmo jeito que na lista, o último item não aparece
# Out:
# ('Passat', 'Crossfox')

# %%
# incluindo uma tupla dentro de outra
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DSS', ('Fusca', 'Gol', 'C4'))
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DSS', ('Fusca', 'Gol', 'C4'))

# %%
# também é possível selecionar o item de uma tupla dentro de outra
nomes_carros[-1][1]
# Out:
# 'Gol'

# %% [markdown]
# ### Exercício

# %% [markdown]
# Em nosso primeiro treinamento de Python para Data Science, nós aprendemos como fazer seleções de itens em listas e em arrays Numpy. O procedimento para seleções em tuplas funciona da mesma forma. Considere a seguinte tupla:

# %%
carros = (
    (
        'Jetta Variant',
        'Motor 4.0 Turbo',
        2003,
        False,
        ('Rodas de liga', 'Travas elétricas', 'Piloto automático')
    ),
    (
        'Passat',
        'Motor Diesel',
        1991,
        True,
        ('Central multimídia', 'Teto panorâmico', 'Freios ABS')
    )
)

# %% [markdown]
# Considere também os seguintes códigos de seleção:
#
#  1) `carros[0][3]`
#
#  2) `carros[-1][-1][-1]`
#
#  3) `carros[0][-1][:2]`
#
# Assinale a alternativa que mostra o resultado obtido com os códigos de seleção acima.

# %% [markdown]
# ## Iterando com tuplas

# %%
nomes_carros = ('Jetta Variant', 'Passat', 'Crossfox', 'DSS')
nomes_carros
# Out:
# ('Jetta Variant', 'Passat', 'Crossfox', 'DSS')

# %%
# funciona do mesmo jeito das listas
for item in nomes_carros:
  print(item)
# Out:
# Jetta Variant
# Passat
# Crossfox
# DSS

# %% [markdown]
# ### Desempacotamento de tuplas

# %%
# posso atribuir cada item a uma variável
carro_1, carro_2, carro_3, carro_4 = nomes_carros
carro_1
# Out:
# 'Jetta Variant'

# %%
carro_2
# Out:
# 'Passat'

# %%
carro_3
# Out:
# 'Crossfox'

# %%
carro_4
# Out:
# 'DSS'

# %%
# posso ignorar os itens usando "_"
_, A, _, B = nomes_carros
A
# Out:
# 'Passat'

# %%
B
# Out:
# 'DSS'

# %%
# posso também usar o * para indicar o restante
_, C, *_ = nomes_carros
C
# Out:
# 'Passat'

# %% [markdown]
# ### `zip()`
# Permite associar listas em diferentes tuplas (primeiro elemento com primeiro elemento...)

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox', 'DS5']

# %%
valores = [88078.64, 106161.94, 72832.16, 124549.07]
valores
# Out:
# [88078.64, 106161.94, 72832.16, 124549.07]

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64),
#  ('Passat', 106161.94),
#  ('Crossfox', 72832.16),
#  ('DS5', 124549.07)]

# %%
for carro, valor in zip(carros, valores):
  print(f'O carro {carro} custa {valor}.')
# Out:
# O carro Jetta Variant custa 88078.64.
# O carro Passat custa 106161.94.
# O carro Crossfox custa 72832.16.
# O carro DS5 custa 124549.07.

# %%
for carro, valor in zip(carros, valores):
  if valor > 100000:
    print(f'O carro {carro} custa mais de 100 mil')
# Out:
# O carro Passat custa mais de 100 mil
# O carro DS5 custa mais de 100 mil

# %% [markdown]
# ### Exercício 1

# %% [markdown]
# O procedimento de iteração em tuplas é o mesmo que aprendemos com listas, no treinamento anterior. Utilizamos a tupla como iterador de um laço `for` simples, ou aninhado, e conseguimos acesso a cada item individualmente.
#
# Para responder esta questão, considere a mesma tupla da atividade anterior:

# %%
carros = (
    (
        'Jetta Variant',
        'Motor 4.0 Turbo',
        2003,
        False,
        ('Rodas de liga', 'Travas elétricas', 'Piloto automático')
    ),
    (
        'Passat',
        'Motor Diesel',
        1991,
        True,
        ('Central multimídia', 'Teto panorâmico', 'Freios ABS')
    )
)

# %% [markdown]
# Observe que se trata de uma tupla (1º nível) com duas tuplas, que representam um conjunto de dados de dois veículos (2º nível), e que uma destas informações (acessórios) vêm também dentro de uma tupla (3º nível). O que precisamos é iterar na tupla `carros` e imprimir **todos os acessórios** que aparecem. O resultado desejado é o seguinte:
#
# ```
# Rodas de liga
# Travas elétricas
# Piloto automático
# Central multimídia
# Teto panorâmico
# Freios ABS
# ```

# %%
# resposta
for carro in carros:
  for item in carro[-1]:
    print(item)
# Out:
# Rodas de liga
# Travas elétricas
# Piloto automático
# Central multimídia
# Teto panorâmico
# Freios ABS

# %% [markdown]
# ### Exercício 2

# %% [markdown]
# Duas ferramentas bastante utilizadas quando iteramos com tuplas são o desempacotamento de tuplas e a built-in function `zip()`.
#
# Com o desempacotamento de tuplas, é possível fazer declarações conjuntas de variáveis e utilizar cada variável individualmente. Por exemplo:
#
# ```nome, valor = ('Passat', 100000.0) ```
#
# A função `zip()` permite gerar um iterador de tuplas, como no exemplo abaixo:
#
# ```
# nomes = ['Passat', 'Crossfox']
# valores = [100000.0, 75000.0]
# list(zip(nomes, valores))
#
# # out
# [('Passat', 100000.0), ('Crossfox', 75000.0)]
# ```
#
# Considerando as duas listas abaixo:

# %%
nomes = ['Passat', 'Crossfox', 'DS5', 'C4', 'Jetta']
kms = [15000, 12000, 32000, 8000, 50000]

# %% [markdown]
# E utilizando o ferramental apresentado acima, marque a alternativa com o código que possibilita a impressão dos nomes dos veículos com quilometragem abaixo de 20.000 km.

# %%
for carro, km in zip(nomes, kms): # notar que não é necessário usar o list, já que não preciso visualizar
  if km < 20000:
    print(carro)
# Out:
# Passat
# Crossfox
# C4

# %% [markdown]
# # 3. Dicionários

# %% [markdown]
# ## Criando dicionários

# %% [markdown]
# Os dicionários são estruturas de informações em que há sempre um dado primário (chave) e dados secundários (valores)

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
valores = [88078.64, 106161.94, 72832.16]
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %% [markdown]
# Exemplo de como trabalhar selecionando valores a partir de uma lista:

# %%
# primeiro, identificamos qual é o índice
carros.index('Passat')
# Out:
# 1

# %%
# então, para sabr qual é o valor do Passat
valores[carros.index('Passat')]
# Out:
# 106161.94

# %% [markdown]
# Usando um dicionário, esse processo é mais fácil

# %%
# construindo o dicionário manualmente
dados = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
type(dados)
# Out:
# dict

# %% [markdown]
# ## Usando `zip()` para criar dicionários

# %% [markdown]
# Com o zip, a gente conseguia criar uma lista de tuplas combinando `list(zip())`

# %%
list(zip(carros, valores))
# Out:
# [('Jetta Variant', 88078.64), ('Passat', 106161.94), ('Crossfox', 72832.16)]

# %% [markdown]
# Podemos criar dicionários de maneira semelhante, associando `dict()`

# %%
dict(zip(carros, valores))
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %% [markdown]
# ### Exercício

# %% [markdown]
# Vimos em nossa última aula algumas maneiras de se criar um dicionário.
#
# Tendo como base as duas listas abaixo:

# %%
nomes = ['Passat', 'Crossfox', 'DS5', 'C4', 'Jetta']
kms = [15000, 12000, 32000, 8000, 50000]

# %% [markdown]
# Marque a alternativa que mostra uma das formas de se criar dicionários a partir de listas.

# %%
dict(zip(nomes, kms))
# Out:
# {'C4': 8000, 'Crossfox': 12000, 'DS5': 32000, 'Jetta': 50000, 'Passat': 15000}

# %% [markdown]
# ## Operações com dicionários

# %%
dados = {'Jetta Variant':88078.64, 'Passat':106161.94, 'Crossfox':72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %% [markdown]
# ### Valor da chave - `dict[key]`
# Retorna o valor referente à chave fornecida

# %%
dados['Passat']
# Out:
# 106161.94

# %% [markdown]
# ### Chave está no dicionário? `key in dict`
# Identifica se a chave está no dicionário

# %%
'Passat' in dados
# Out:
# True

# %%
'Gol' in dados
# Out:
# False

# %%
'Gol' not in dados
# Out:
# True

# %% [markdown]
# ### Tamanho do dicionário - `len(dict)`
# Retorna o tamanho do dicionário (número de chaves)

# %%
len(dados)
# Out:
# 3

# %% [markdown]
# ### Inclui novo item - `dict[newkey] = newvalue`
# Inclui novo valor no dicionário

# %%
dados['DS5'] = 124549.07
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %% [markdown]
# ### Remover item - `del dict[key]`
# Remove item do dicionário

# %%
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
del dados['Passat']
dados
# Out:
# {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}

# %% [markdown]
# ### Exercício
#
# Utilize o dicionário `dados` para responder a questão:

# %%
dados = {
    'Passat': {
        'ano': 2012,
        'km': 50000,
        'valor': 75000,
        'acessorios': ['Airbag', 'ABS']
    }, 
    'Crossfox': {
        'ano': 2015,
        'km': 35000,
        'valor': 25000
    }
}

# %% [markdown]
# Note que `dados` tem dois itens, onde a chave (*key*) é o nome do veículo e o valor (*value*) é um dicionário com informações sobre este veículo (ano, quilometragem, valor e acessórios). Nossa tarefa nesta atividade é aprender como acessar as informações de um dicionário dentro de outro dicionário.
#
# Queremos o seguinte:
#
# 1) Testar se a chave `acessorios` existe no dicionário de informações do carro Crossfox (Resposta: `False`)

# %%
'acessorios' in dados['Crossfox']
# Out:
# False

# %% [markdown]
# 2) Testar se a chave `acessorios` existe no dicionário de informações do carro Passat (Resposta: `True`)

# %%
'acessorios' in dados['Passat']
# Out:
# True

# %% [markdown]
# 3) Obter o valor do carro `Crossfox` (Resposta: `25000`)

# %%
dados['Crossfox']['valor']
# Out:
# 25000

# %% [markdown]
# 4) Acessar o último acessório do carro `Passat` (Resposta: `'ABS'`)

# %%
dados['Passat']['acessorios'][-1]
# Out:
# 'ABS'

# %% [markdown]
# ## Métodos de dicionários

# %%
dados = {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}
dados
# Out:
# {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}

# %% [markdown]
# ### Atualiza o dictionário - `dict.update()`

# %%
# posso adicionar um novo item
dados.update({'Passat': 106161.94})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.94}

# %%
# posso atualizar o valor de algum item
dados.update({'Passat': 106161.96})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.96}

# %%
# posso atualizar e adicionar ao mesmo tempo
dados.update({'Passat': 106161.95, 'Fusca': 150000})
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %% [markdown]
# ### Criar cópia - `dict.copy()`
# Se eu apenas usar `dadosCopy = dados`, eu vou apenas alterar o rótulo para uma mesma variável. Então eu preciso fazer sempre a cópia, se eu quiser fazer alterações em uma variável e não alterar a original.

# %%
dadosCopy = dados.copy()
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
del dadosCopy['Fusca']
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %% [markdown]
# ### Retorna valor e remove chave - `dict.pop(key)`

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %%
dadosCopy.pop('Passat')
# Out:
# 106161.95

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16, 'DS5': 124549.07, 'Jetta Variant': 88078.64}

# %% [markdown]
# É possível fazer com que o método retorne uma mensagem de erro se não encontrar a chave

# %%
dadosCopy.pop('Passat', 'Chave não encontrada')
# Out:
# 'Chave não encontrada'

# %%
dadosCopy.pop('DS5', 'Chave não encontrada')
# Out:
# 124549.07

# %%
dadosCopy
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64}

# %% [markdown]
# ### Remover todos os itens - `dict.clear()`

# %%
dadosCopy.clear()
dadosCopy
# Out:
# {}

# %% [markdown]
# ### Exercício
# Considere o dicionário abaixo:

# %%
dados = {'Jetta': 88000, 'Crossfox': 72000, 'DS5': 124000}

# %% [markdown]
# ## Iterando em dicionários

# %%
dados = {'Crossfox': 72832.16,
 'DS5': 124549.07,
 'Fusca': 150000,
 'Jetta Variant': 88078.64,
 'Passat': 106161.95}
dados
# Out:
# {'Crossfox': 72832.16,
#  'DS5': 124549.07,
#  'Fusca': 150000,
#  'Jetta Variant': 88078.64,
#  'Passat': 106161.95}

# %% [markdown]
# ### Lista de chaves - `dict.keys()`

# %%
dados.keys()
# Out:
# dict_keys(['Crossfox', 'DS5', 'Fusca', 'Jetta Variant', 'Passat'])

# %%
for key in dados.keys():
  print(dados[key])
# Out:
# 72832.16
# 124549.07
# 150000
# 88078.64
# 106161.95

# %% [markdown]
# ### Lista de valores - `dict.values()`

# %%
dados.values()
# Out:
# dict_values([72832.16, 124549.07, 150000, 88078.64, 106161.95])

# %% [markdown]
# ### Converte em tupla - `dict.items()`

# %%
dados.items()
# Out:
# dict_items([('Crossfox', 72832.16), ('DS5', 124549.07), ('Fusca', 150000), ('Jetta Variant', 88078.64), ('Passat', 106161.95)])

# %%
for item in dados.items():
  print(item)
# Out:
# ('Crossfox', 72832.16)
# ('DS5', 124549.07)
# ('Fusca', 150000)
# ('Jetta Variant', 88078.64)
# ('Passat', 106161.95)

# %%
for key, value in dados.items():
  if value < 100000:
    print(key)
# Out:
# Crossfox
# Jetta Variant

# %% [markdown]
# ### Exercício

# %%
dados = {
    'Crossfox': {'valor': 72000, 'ano': 2005}, 
    'DS5': {'valor': 125000, 'ano': 2015}, 
    'Fusca': {'valor': 150000, 'ano': 1976}, 
    'Jetta': {'valor': 88000, 'ano': 2010}, 
    'Passat': {'valor': 106000, 'ano': 1998}
}

# %% [markdown]
# Selecione a alternativa que apresenta o código que imprime somente os nomes dos veículos com ano de fabricação maior ou igual a 2000.

# %%
for carro in dados.keys():  
  if dados[carro]['ano'] >= 2000:
    print(carro)
# Out:
# Crossfox
# DS5
# Jetta

# %%
for item in dados.items():
  if item[1]['ano'] >= 2000:
    print(item[0])
# Out:
# Crossfox
# DS5
# Jetta

# %% [markdown]
# # 4. Funções e pacotes

# %% [markdown]
# ## Built-in function

# %%
dados = {'Jetta Variant': 88078.64, 'Passat': 106161.94, 'Crossfox': 72832.16}
dados
# Out:
# {'Crossfox': 72832.16, 'Jetta Variant': 88078.64, 'Passat': 106161.94}

# %%
valores = []
for valor in dados.values():
  valores.append(valor)
valores
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
list(dados.values())
# Out:
# [88078.64, 106161.94, 72832.16]

# %%
soma = 0
for valor in dados.values():
  soma += valor
soma
# Out:
# 267072.74

# %%
sum(dados.values())
# Out:
# 267072.74

# %% [markdown]
# ## Definindo funções sem e com parâmetros

# %% [markdown]
# ### sem parâmetro

# %%
def media():
  valor = (1 + 2 + 3) / 3
  print(valor)

media()
# Out:
# 2.0

# %% [markdown]
# ### com parâmetro

# %%
def media(number_1, number_2, number_3):
  valor = (number_1 + number_2 + number_3) / 3
  print(valor)

# %%
media(1, 2 ,3)
# Out:
# 2.0

# %%
media(23, 45, 67)
# Out:
# 45.0

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  print(valor)

# %%
resultado = media([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 5.0

# %% [markdown]
# Como dentro da função o valor não é retornado, apenas "impresso", resultado não recebe o valor final do cálculo

# %%
type(resultado)
# Out:
# NoneType

# %% [markdown]
# ### Exercício
# Uma tarefa importante em um trabalho de cientista de dados é o tratamento do dataset que vamos utilizar. Essa tarefa é dividida em várias etapas e uma delas é a sumarização dos dados, onde obtemos estatísticas descritivas para ajudar nas tomadas de decisão.
#
# Algumas sumarizações precisam de um conjunto de elaborações, que devem ser desenvolvidas pelo próprio pesquisador. Neste ponto, as funções são bastante úteis no trabalho do cientista de dados. Com elas, podemos definir um conjunto de tarefas específicas, que recebem entradas e retornam resultados, e reutilizar esta codificação em outras partes de nosso projeto.
#
# Um exemplo disso em nosso projeto é o cálculo da quilometragem média que um veículo rodou por ano. Não existe uma função pronta para o cálculo desta estatística em Python, e por isso precisamos escrever uma função que obtenha este valor.
#
# Considere o conjunto de informações abaixo para responder o problema:

# %%
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %% [markdown]
# A estrutura a seguir é a definição de uma função que obtém e imprime a quilometragem média anual de cada veículo em um dicionário com a estrutura do dicionário dados acima:

# %%
def km_media(dataset, ano_atual):
    for item in dataset.items():
        result = item[1]['km'] / (ano_atual - item[1]['ano'])
        print(result)

# %%
km_media(dados, 2019)
# Out:
# 2500.0
# 4250.0
# 3250.0
# 7000.0
# 3100.0

# %% [markdown]
# ## Definindo funções que retornam valores

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return valor

# %%
resultado = media([1, 2, 3, 4, 5, 6, 7, 8, 9])
resultado
# Out:
# 5.0

# %% [markdown]
# ## Definindo funções que retornam mais de um valor

# %%
def media(lista):
  valor = sum(lista) / len(lista)
  return (valor, len(lista))

media([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# (5.0, 9)

# %% [markdown]
# ## Exercício
# No problema anterior, definimos uma função para obter a quilometragem média anual de cada veículo em um dataset. Precisamos melhorar um pouco a nossa função e obter valores que possam ser reutilizados em outras partes do nosso projeto.
#
# Aprendemos em nosso último vídeo como criar funções que retornam valores, e é isso que precisamos para resolver este problema. A estrutura a seguir é a definição de uma função que calcula as quilometragens médias anuais de cada veículo e retorna um dicionário com os nomes dos veículos como chaves e as quilometragens médias como valores:

# %%
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
def km_media(dataset, ano_atual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (ano_atual - item[1]['ano'])
        result.update({item[0]: result})
    return result

# %%
km_media(dados, 2019)
# Out:
# {'Crossfox': 2500.0,
#  'DS5': 4250.0,
#  'Fusca': 3250.0,
#  'Jetta': 7000.0,
#  'Passat': 3100.0}

# %% [markdown]
# A nossa função `km_media()` já retorna valores que podem ser trabalhados em outras partes do nosso projeto. Uma elaboração extra, que também pode ser interessante, principalmente para a criação de DataFrames (próximas aulas), é a atualização do próprio `input` da função. Podemos fazer com que a nossa função retorne as informações do dicionário dados, incluindo as informações de quilometragem média anual.
#
# A estrutura a seguir é a definição de uma função que calcula as quilometragens médias anuais de cada veículo, atualiza o dicionário de entrada e retorna este dicionário:

# %%
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
def km_media(dataset, ano_atual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (ano_atual - item[1]['ano'])
        item[1].update({'km_media': media})
        result.update({item[0]: item[1]})
    return result

# %% [markdown]
# # 5. Básico de Pandas

# %%
import pandas as pd

# %% [markdown]
# **Series** são arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado.
#
# `s = pd.Series(dados, index = index)`
#
# **Dataframes** também são dados estruturados, mas bidimensionais, com rótulos nas linhas e colunas.
#
# `df = pd.DataFrame(dados, index = index, columns = columns)`
#
# O argumento `dados` pode ser uma lista, um dicionário, uma array NumPy, ou outra Series ou Dataframe.

# %% [markdown]
# ## Estrutura de dados

# %% [markdown]
# ### Criando uma Series a partir de uma lista

# %%
carros = ['Jetta Variant', 'Passat', 'Crossfox']
carros
# Out:
# ['Jetta Variant', 'Passat', 'Crossfox']

# %%
pd.Series(carros)
# Out:
# 0    Jetta Variant
# 1           Passat
# 2         Crossfox
# dtype: object

# %% [markdown]
# ### Criando um DataFrame a partir de uma lista de dicionários

# %%
dados = [
    {'Nome': 'Jetta Variant', 'Motor': 'Motor 4.0 Turbo', 'Ano': 2003, 'Quilometragem': 44410.0, 'Zero_km': False, 'Valor': 88078.64},
    {'Nome': 'Passat', 'Motor': 'Motor Diesel', 'Ano': 1991, 'Quilometragem': 5712.0, 'Zero_km': False, 'Valor': 106161.94},
    {'Nome': 'Crossfox', 'Motor': 'Motor Diesel V8', 'Ano': 1990, 'Quilometragem': 37123.0, 'Zero_km': False, 'Valor': 72832.16}
]

# %%
dataset = pd.DataFrame(dados)

# %%
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %%
# para alterar a ordem das colunas
dataset[['Nome', 'Ano', 'Motor', 'Quilometragem', 'Zero_km', 'Valor']]
# Out:
#             Nome   Ano            Motor  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  2003  Motor 4.0 Turbo        44410.0    False   88078.64
# 1         Passat  1991     Motor Diesel         5712.0    False  106161.94
# 2       Crossfox  1990  Motor Diesel V8        37123.0    False   72832.16

# %% [markdown]
# ### Criando um DataFrame a partir de um dicionário

# %%
dados = {
    'Nome': ['Jetta Variant', 'Passat', 'Crossfox'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8'],
    'Ano': [2003, 1991, 1990],
    'Quilometragem': [44410.0, 5712.0, 37123.0],
    'Zero_km': [False, False, False],
    'Valor': [88078.64, 106161.94, 72832.16]
}

# %%
dataset = pd.DataFrame(dados)
dataset
# Out:
#             Nome            Motor   Ano  Quilometragem  Zero_km      Valor
# 0  Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False   88078.64
# 1         Passat     Motor Diesel  1991         5712.0    False  106161.94
# 2       Crossfox  Motor Diesel V8  1990        37123.0    False   72832.16

# %% [markdown]
# ### Criando a partir de um arquivo externo

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python para Data Science/03_pandas/data/db.csv', 
                      sep = ';', index_col = 'Nome')
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %% [markdown]
# ### Exercício

# %%
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
def km_media(dataset, ano_atual):
    result = {}
    for item in dataset.items():
        media = item[1]['km'] / (ano_atual - item[1]['ano'])
        item[1].update({ 'km_media': media })
        result.update({ item[0]: item[1] })

    return result

km_media(dados, 2019)
# Out:
# {'Crossfox': {'ano': 2005, 'km': 35000, 'km_media': 2500.0},
#  'DS5': {'ano': 2015, 'km': 17000, 'km_media': 4250.0},
#  'Fusca': {'ano': 1979, 'km': 130000, 'km_media': 3250.0},
#  'Jetta': {'ano': 2011, 'km': 56000, 'km_media': 7000.0},
#  'Passat': {'ano': 1999, 'km': 62000, 'km_media': 3100.0}}

# %%
pd.DataFrame(km_media(dados, 2019)).T
# Out:
#                 km     ano  km_media
# Crossfox   35000.0  2005.0    2500.0
# DS5        17000.0  2015.0    4250.0
# Fusca     130000.0  1979.0    3250.0
# Jetta      56000.0  2011.0    7000.0
# Passat     62000.0  1999.0    3100.0

# %% [markdown]
# ## Seleções com DataFrames

# %%
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %% [markdown]
# ### Selecionando colunas

# %%
dataset['Valor']
# Out:
# 0       88078.64
# 1      106161.94
# 2       72832.16
# 3      124549.07
# 4       92612.10
#          ...
# 253     51759.58
# 254     51667.06
# 255     68934.03
# 256    122110.90
# 257     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor']) # note que desse modo ele retorna uma Series
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]
# Out:
#          Valor
# 0     88078.64
# 1    106161.94
# 2     72832.16
# 3    124549.07
# 4     92612.10
# ..         ...
# 253   51759.58
# 254   51667.06
# 255   68934.03
# 256  122110.90
# 257   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[['Valor']]) # com dois colchetes ele retorna um dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Selecionando linhas

# %%
dataset[1:4]
# Out:
#        Nome            Motor   Ano  Quilometragem  Zero_km  \
# 1    Passat     Motor Diesel  1991         5712.0    False
# 2  Crossfox  Motor Diesel V8  1990        37123.0    False
# 3       DS5  Motor 2.4 Turbo  2019            NaN     True
#
#                                           Acessórios      Valor
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %% [markdown]
# ### Utilizando `.loc`
# Retorna o valor a partir da chave fornecida. É importante garantir que o dado está estruturado com a chave que vai ser utilizada.

# %%
dataset.loc['Passat'] # um colchete retorna Series, dois retorna DataFrame
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                               5712.0
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                    106161.94
# Name: Passat, dtype: object

# %%
dataset.loc[['Passat', 'Crossfox']]
# Out:
#                     Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat       Motor Diesel  1991         5712.0    False
# Crossfox  Motor Diesel V8  1990        37123.0    False
#
#                                                  Acessórios      Valor
# Nome
# Passat    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox  ['Piloto automático', 'Controle de estabilidad...   72832.16

# %% [markdown]
# ### Utilizanto `.iloc[]`
# Retorna o valor a partir do índice (localização fornecida)

# %%
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.iloc[[1]]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[1:4, [0,5,2]] # funciona do mesmo jeito dos arrays
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %% [markdown]
# ### Exercício

# %%
import pandas as pd

dados = {
    'Nome': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Ano': [2019, 2003, 1991, 2019, 1990],
    'Quilometragem': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Zero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(dados)

# %%
dataset[['Nome', 'Ano', 'Quilometragem', 'Valor']][1:3]
# Out:
#        Nome   Ano  Quilometragem     Valor
# 1    Passat  2003         5712.0  106000.0
# 2  Crossfox  1991        37123.0   72000.0

# %% [markdown]
# ### Exercício 2

# %%
import pandas as pd

dados = {
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Ano': [2019, 2003, 1991, 2019, 1990],
    'Quilometragem': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Zero_km': [True, False, False, True, False],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0]
}

dataset = pd.DataFrame(dados, index = ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Fusca'])
dataset
# Out:
#                     Motor   Ano  Quilometragem  Zero_km     Valor
# Jetta     Motor 4.0 Turbo  2019            0.0     True   88000.0
# Passat       Motor Diesel  2003         5712.0    False  106000.0
# Crossfox  Motor Diesel V8  1991        37123.0    False   72000.0
# DS5             Motor 2.0  2019            0.0     True   89000.0
# Fusca           Motor 1.6  1990       120000.0    False   32000.0

# %%
dataset.loc[['Passat', 'DS5'], ['Motor', 'Valor']]
# Out:
#                Motor     Valor
# Passat  Motor Diesel  106000.0
# DS5        Motor 2.0   89000.0

# %%
dataset.iloc[[1,3], [0,-1]]
# Out:
#                Motor     Valor
# Passat  Motor Diesel  106000.0
# DS5        Motor 2.0   89000.0

# %% [markdown]
# ## Queries com Dataframes

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python para Data Science/03_pandas/data/db.csv', 
                      sep = ';', index_col = 'Nome')
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.Motor
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
dataset.Motor == 'Motor Diesel'
# Out:
# Nome
# Jetta Variant            False
# Passat                    True
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5          True
# Macan                    False
# Name: Motor, Length: 258, dtype: bool

# %%
select = dataset.Motor == 'Motor Diesel'

# %%
dataset[select]
# Out:
#                               Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat                 Motor Diesel  1991         5712.0    False
# Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# Sorento                Motor Diesel  2019            NaN     True
# New Fiesta Hatch       Motor Diesel  2017       118895.0    False
# Kangoo Express         Motor Diesel  2007        29132.0    False
# Fit                    Motor Diesel  2013        44329.0    False
# Cielo Hatch            Motor Diesel  2019            NaN     True
# Symbol                 Motor Diesel  2016       117714.0    False
# A4 Sedan               Motor Diesel  2002        30511.0    False
# A4 Avant               Motor Diesel  2014        17357.0    False
# Silver Shadow          Motor Diesel  2015        99052.0    False
# Camry                  Motor Diesel  2019            NaN     True
# Clio                   Motor Diesel  1990        66437.0    False
# ...

# %%
dataset[(select) & (dataset.Zero_km == True)]
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %% [markdown]
# ### Utilizando o método Query

# %%
dataset.query('Motor == "Motor Diesel" and Zero_km')
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %% [markdown]
# ## Iterando nos DataFrames

# %%
for item in dataset:
  print(item)

# faz iteração por coluna
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Valor

# %%
for index, row in dataset.iterrows():
  if (2019 - row['Ano']) != 0:
    dataset.loc[index, 'Km_media'] = row['Quilometragem'] / (2019 - row['Ano'])
  else: 
    dataset.loc[index, 'Km_media'] = 0

dataset
# Out:
#                     Motor   Ano  Quilometragem  Zero_km     Valor     Km_media
# Jetta     Motor 4.0 Turbo  2019            0.0     True   88000.0     0.000000
# Passat       Motor Diesel  2003         5712.0    False  106000.0   357.000000
# Crossfox  Motor Diesel V8  1991        37123.0    False   72000.0  1325.821429
# DS5          Motor Diesel  2019            0.0     True   89000.0     0.000000
# Fusca           Motor 1.6  1990       120000.0    False   32000.0  4137.931034

# %% [markdown]
# ## Tratamento de dados

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python para Data Science/03_pandas/data/db.csv', 
                      sep = ';', index_col = 'Nome')
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(2)
# memory usage: 20.4+ KB

# %%
dataset.Quilometragem.isna()
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %% [markdown]
# ### Preenche NA com o valor dado

# %%
dataset.fillna(0, inplace = True)

# %% [markdown]
# ### Remove linhas com NA

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Python para Data Science/03_pandas/data/db.csv', 
                      sep = ';', index_col = 'Nome')
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.dropna(subset = ['Quilometragem'], inplace = True)

# %%
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# Palio Weekend                  Motor 1.8 16v  2012        10728.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...
